# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data

# If that didn't work try using the local host URL as shown in the video

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id         name symbol                  slug  num_market_pairs  \
# 0       1      Bitcoin    BTC               bitcoin             10494
# 1    1027     Ethereum    ETH              ethereum              7551
# 2     825  Tether USDt   USDT                tether             63709
# 3    1839          BNB    BNB                   bnb              1682
# 4      52          XRP    XRP                   xrp              1114
# 5    3408         USDC   USDC              usd-coin             14451
# 6    5426       Solana    SOL                solana               535
# 7    2010      Cardano    ADA               cardano               946
# 8      74     Dogecoin   DOGE              dogecoin               806
# 9    1958         TRON    TRX                  tron               852
# 10  11419      Toncoin    TON               toncoin               158
# 11   4943          Dai    DAI  multi-collateral-dai              2671
# 12   3890      Polygon  MATIC               polygon              1002
# 13   6636     Polkadot    DOT          polkadot-new               592
# 14      2     Litecoin    LTC              litecoin              1011
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2013-08-04T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2020-04-10T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2017-09-13T00:00:00.000Z
# 10  2021-08-26T13:40:22.000Z
# 11  2019-11-22T00:00:00.000Z
# 12  2019-04-28T00:00:00.000Z
# 13  2020-08-19T00:00:00.000Z
# 14  2013-04-28T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 7   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 8   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 9   [media, payments, tron-ecosystem, dwf-labs-por...           NaN
# 10  [pos, ftx-bankruptcy-estate, dwf-labs-portfoli...           NaN
# 11  [defi, stablecoin, asset-backed-stablecoin, et...           NaN
# 12  [pos, platform, enterprise-solutions, zero-kno...  1.000000e+10
# 13  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 14        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.951451e+07  1.951451e+07            False       NaN         1
# 1         1.202581e+08  1.202581e+08             True       NaN         2
# 2         8.352701e+10  8.662567e+10             True       NaN         3
# 3         1.538448e+08  1.538448e+08            False       NaN         4
# 4         5.344103e+10  9.998836e+10            False       NaN         5
# 5         2.512296e+10  2.512296e+10            False       NaN         6
# 6         4.162580e+08  5.600333e+08             True       NaN         7
# 7         3.521102e+10  3.625937e+10            False       NaN         8
# 8         1.414225e+11  1.414225e+11             True       NaN         9
# 9         8.893961e+10  8.893967e+10             True       NaN        10
# 10        3.431892e+09  5.047559e+09             True       NaN        11
# 11        5.347889e+09  5.347889e+09             True       NaN        12
# 12        9.299803e+09  1.000000e+10            False       NaN        13
# 13        1.234087e+09  1.366347e+09             True       NaN        14
# 14        7.376504e+07  8.400000e+07            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                                NaN                       NaN      None
# 9                       7.165966e+10              6.126085e+09      None
# 10                      3.414167e+09              6.580624e+09      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2023-10-15T14:37:00.000Z     26904.023055          5.216794e+09
# 1   2023-10-15T14:37:00.000Z      1555.007129          2.384726e+09
# 2   2023-10-15T14:37:00.000Z         1.000208          1.052992e+10
# 3   2023-10-15T14:37:00.000Z       209.008087          3.261842e+08
# 4   2023-10-15T14:37:00.000Z         0.486535          3.671042e+08
# 5   2023-10-15T14:37:00.000Z         1.000189          1.040241e+09
# 6   2023-10-15T14:37:00.000Z        21.804841          1.476187e+08
# 7   2023-10-15T14:37:00.000Z         0.246091          7.356892e+07
# 8   2023-10-15T14:37:00.000Z         0.059279          1.112525e+08
# 9   2023-10-15T14:37:00.000Z         0.085489          1.784508e+08
# 10  2023-10-15T14:37:00.000Z         1.927447          1.597705e+07
# 11  2023-10-15T14:37:00.000Z         0.999869          4.631173e+07
# 12  2023-10-15T14:37:00.000Z         0.515752          1.631103e+08
# 13  2023-10-15T14:37:00.000Z         3.745475          5.189813e+07
# 14  2023-10-15T14:37:00.000Z        61.556994          1.225576e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      -36.1852                     0.021811
# 1                      -35.8978                    -0.128760
# 2                      -21.1978                     0.009103
# 3                       26.0581                    -0.134875
# 4                      -23.6951                    -0.148607
# 5                      -38.7956                     0.002492
# 6                      -44.6181                    -0.336948
# 7                      -18.0866                    -0.108945
# 8                       -8.7810                     0.057537
# 9                       50.3281                     0.072255
# 10                      -8.5734                    -0.248837
# 11                     -46.2381                    -0.025582
# 12                     -11.9578                    -0.071702
# 13                       6.7335                    -0.039380
# 14                      -9.9943                    -0.077841
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       0.067962                    -3.699811
# 1                       0.290450                    -4.713715
# 2                       0.018390                    -0.019422
# 3                       1.275514                    -1.245499
# 4                       0.232795                    -6.606966
# 5                       0.008054                     0.033741
# 6                      -0.781276                    -6.591421
# 7                      -0.370917                    -4.228938
# 8                      -0.057166                    -3.163110
# 9                       0.077575                    -2.822659
# 10                     -1.265293                    -6.153662
# 11                     -0.008545                    -0.027596
# 12                     -0.532500                    -8.307251
# 13                      0.006417                    -7.057717
# 14                      0.018271                    -5.819081
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       2.211918                     -7.568406
# 1                      -3.873944                    -14.710023
# 2                       0.006100                      0.144447
# 3                      -1.214001                    -10.411180
# 4                      -1.007613                    -18.256075
# 5                       0.009315                      0.010881
# 6                      15.588291                     -5.958618
# 7                      -0.777740                    -10.193967
# 8                      -3.899941                    -14.478035
# 9                       2.790688                     12.901608
# 10                     -1.901005                     33.469505
# 11                      0.045558                      0.031249
# 12                     -0.457822                    -17.319742
# 13                     -8.371744                    -21.024911
# 14                     -3.105393                    -21.170307
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                     -11.111095          5.250187e+11
# 1                     -18.750937          1.870023e+11
# 2                      -0.006775          8.354438e+10
# 3                     -14.235754          3.215481e+10
# 4                     -34.247957          2.600092e+10
# 5                       0.010323          2.512771e+10
# 6                     -19.783681          9.076440e+09
# 7                     -21.736501          8.665105e+09
# 8                     -15.328685          8.383409e+09
# 9                       7.301636          7.603324e+09
# 10                     42.563317          6.614789e+09
# 11                      0.042034          5.347187e+09
# 12                    -34.007368          4.796395e+09
# 13                    -29.334600          4.622243e+09
# 14                    -33.139746          4.540754e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          49.8546                        5.649845e+11
# 1                          17.7573                        1.870023e+11
# 2                           7.9333                        8.664368e+10
# 3                           3.0534                        3.215481e+10
# 4                           2.4690                        4.865349e+10
# 5                           2.3860                        2.512771e+10
# 6                           0.8619                        1.221144e+10
# 7                           0.8228                        1.107408e+10
# 8                           0.7960                        8.383409e+09
# 9                           0.7220                        7.603329e+09
# 10                          0.6281                        9.728900e+09
# 11                          0.5078                        5.347187e+09
# 12                          0.4555                        5.157523e+09
# 13                          0.4389                        5.117617e+09
# 14                          0.4312                        5.170787e+09
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2023-10-15T14:37:00.000Z          NaN           NaN
# 1           None  2023-10-15T14:37:00.000Z          NaN           NaN
# 2           None  2023-10-15T14:37:00.000Z       1027.0      Ethereum
# 3           None  2023-10-15T14:37:00.000Z          NaN           NaN
# 4           None  2023-10-15T14:37:00.000Z          NaN           NaN
# 5           None  2023-10-15T14:37:00.000Z       1027.0      Ethereum
# 6           None  2023-10-15T14:37:00.000Z          NaN           NaN
# 7           None  2023-10-15T14:37:00.000Z          NaN           NaN
# 8           None  2023-10-15T14:37:00.000Z          NaN           NaN
# 9           None  2023-10-15T14:37:00.000Z          NaN           NaN
# 10          None  2023-10-15T14:37:00.000Z          NaN           NaN
# 11          None  2023-10-15T14:37:00.000Z       1027.0      Ethereum
# 12          None  2023-10-15T14:37:00.000Z          NaN           NaN
# 13          None  2023-10-15T14:37:00.000Z          NaN           NaN
# 14          None  2023-10-15T14:37:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             ETH      ethereum  0x6b175474e89094c44da98b954eedeac495271d0f
# 12             NaN           NaN                                         NaN
# 13             NaN           NaN                                         NaN
# 14             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2023-10-15 16:38:55.973271
# 1  2023-10-15 16:38:55.973271
# 2  2023-10-15 16:38:55.973271
# 3  2023-10-15 16:38:55.973271
# 4  2023-10-15 16:38:55.973271
# 5  2023-10-15 16:38:55.973271
# 6  2023-10-15 16:38:55.973271
# 7  2023-10-15 16:38:55.973271
# 8  2023-10-15 16:38:55.973271
# 9  2023-10-15 16:38:55.973271
# 10 2023-10-15 16:38:55.973271
# 11 2023-10-15 16:38:55.973271
# 12 2023-10-15 16:38:55.973271
# 13 2023-10-15 16:38:55.973271
# 14 2023-10-15 16:38:55.973271

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data
    
    # Use this if you just want to keep it in a dataframe
    #df2 = pd.json_normalize(data['data'])
    #df2['Timestamp'] = pd.to_datetime('now')
    #df= pd.concat([df, df2])


    # Use this if you want to create a csv and append data to it
    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df
    
    if not os.path.isfile(r'/Users/sahinbasol/API.csv'):
        df.to_csv(r'/Users/sahinbasol/API.csv', header='column_names')
    else: 
        df.to_csv(r'/Users/sahinbasol/API.csv', mode='a', header=False)


    #if not os.path.isfile(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv'):
        #df.to_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv', header='column_names')
    #else:
        #df.to_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv', mode='a', header=False)
        
    #Then to read in the file: df = pd.read_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv')

# If that didn't work try using the local host URL as shown in the video

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# API Runner completed
# API Runner completed
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 8
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
print(pd. __version__) #append dep.
# Out:
# 2.0.3

# %%
#to read
df12 = pd.read_csv(r'/Users/sahinbasol/API.csv')
df12
# Out:
#     Unnamed: 0     id         name symbol                  slug  \
# 0            0      1      Bitcoin    BTC               bitcoin
# 1            1   1027     Ethereum    ETH              ethereum
# 2            2    825  Tether USDt   USDT                tether
# 3            3   1839          BNB    BNB                   bnb
# 4            4     52          XRP    XRP                   xrp
# 5            5   3408         USDC   USDC              usd-coin
# 6            6   5426       Solana    SOL                solana
# 7            7   2010      Cardano    ADA               cardano
# 8            8     74     Dogecoin   DOGE              dogecoin
# 9            9   1958         TRON    TRX                  tron
# 10          10  11419      Toncoin    TON               toncoin
# 11          11   4943          Dai    DAI  multi-collateral-dai
# 12          12   3890      Polygon  MATIC               polygon
# 13          13   6636     Polkadot    DOT          polkadot-new
# 14          14      2     Litecoin    LTC              litecoin
# 15           0      1      Bitcoin    BTC               bitcoin
# 16           1   1027     Ethereum    ETH              ethereum
# 17           2    825  Tether USDt   USDT                tether
# 18           3   1839          BNB    BNB                   bnb
# 19           4     52          XRP    XRP                   xrp
# 20           5   3408         USDC   USDC              usd-coin
# 21           6   5426       Solana    SOL                solana
# 22           7   2010      Cardano    ADA               cardano
# 23           8     74     Dogecoin   DOGE              dogecoin
# 24           9   1958         TRON    TRX                  tron
# 25          10  11419      Toncoin    TON               toncoin
# 26          11   4943          Dai    DAI  multi-collateral-dai
# 27          12   3890      Polygon  MATIC               polygon
# 28          13   6636     Polkadot    DOT          polkadot-new
# 29          14      2     Litecoin    LTC              litecoin
# 30           0      1      Bitcoin    BTC               bitcoin
# 31           1   1027     Ethereum    ETH              ethereum
# 32           2    825  Tether USDt   USDT                tether
# 33           3   1839          BNB    BNB                   bnb
# 34           4     52          XRP    XRP                   xrp
# 35           5   3408         USDC   USDC              usd-coin
# 36           6   5426       Solana    SOL                solana
# 37           7   2010      Cardano    ADA               cardano
# 38           8     74     Dogecoin   DOGE              dogecoin
# 39           9   1958         TRON    TRX                  tron
# 40          10  11419      Toncoin    TON               toncoin
# 41          11   4943          Dai    DAI  multi-collateral-dai
# 42          12   3890      Polygon  MATIC               polygon
# 43          13   6636     Polkadot    DOT          polkadot-new
# 44          14      2     Litecoin    LTC              litecoin
#
#     num_market_pairs                date_added  \
# 0              10494  2010-07-13T00:00:00.000Z
# 1               7551  2015-08-07T00:00:00.000Z
# 2              63709  2015-02-25T00:00:00.000Z
# 3               1682  2017-07-25T00:00:00.000Z
# 4               1114  2013-08-04T00:00:00.000Z
# 5              14451  2018-10-08T00:00:00.000Z
# 6                535  2020-04-10T00:00:00.000Z
# 7                946  2017-10-01T00:00:00.000Z
# 8                806  2013-12-15T00:00:00.000Z
# 9                852  2017-09-13T00:00:00.000Z
# 10               158  2021-08-26T13:40:22.000Z
# 11              2671  2019-11-22T00:00:00.000Z
# 12              1002  2019-04-28T00:00:00.000Z
# 13               592  2020-08-19T00:00:00.000Z
# 14              1011  2013-04-28T00:00:00.000Z
# 15             10494  2010-07-13T00:00:00.000Z
# 16              7551  2015-08-07T00:00:00.000Z
# 17             63709  2015-02-25T00:00:00.000Z
# 18              1682  2017-07-25T00:00:00.000Z
# 19              1114  2013-08-04T00:00:00.000Z
# 20             14451  2018-10-08T00:00:00.000Z
# 21               535  2020-04-10T00:00:00.000Z
# 22               946  2017-10-01T00:00:00.000Z
# 23               806  2013-12-15T00:00:00.000Z
# 24               852  2017-09-13T00:00:00.000Z
# 25               158  2021-08-26T13:40:22.000Z
# 26              2671  2019-11-22T00:00:00.000Z
# 27              1002  2019-04-28T00:00:00.000Z
# 28               592  2020-08-19T00:00:00.000Z
# 29              1011  2013-04-28T00:00:00.000Z
# 30             10494  2010-07-13T00:00:00.000Z
# 31              7551  2015-08-07T00:00:00.000Z
# 32             63709  2015-02-25T00:00:00.000Z
# 33              1682  2017-07-25T00:00:00.000Z
# 34              1114  2013-08-04T00:00:00.000Z
# 35             14451  2018-10-08T00:00:00.000Z
# 36               535  2020-04-10T00:00:00.000Z
# 37               946  2017-10-01T00:00:00.000Z
# 38               806  2013-12-15T00:00:00.000Z
# 39               852  2017-09-13T00:00:00.000Z
# 40               158  2021-08-26T13:40:22.000Z
# 41              2671  2019-11-22T00:00:00.000Z
# 42              1002  2019-04-28T00:00:00.000Z
# 43               592  2020-08-19T00:00:00.000Z
# 44              1011  2013-04-28T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   ['mineable', 'pow', 'sha-256', 'store-of-value...  2.100000e+07
# 1   ['pos', 'smart-contracts', 'ethereum-ecosystem...           NaN
# 2   ['payments', 'stablecoin', 'asset-backed-stabl...           NaN
# 3   ['marketplace', 'centralized-exchange', 'payme...           NaN
# 4   ['medium-of-exchange', 'enterprise-solutions',...  1.000000e+11
# 5   ['medium-of-exchange', 'stablecoin', 'asset-ba...           NaN
# 6   ['pos', 'platform', 'solana-ecosystem', 'cms-h...           NaN
# 7   ['dpos', 'pos', 'platform', 'research', 'smart...  4.500000e+10
# 8   ['mineable', 'pow', 'scrypt', 'medium-of-excha...           NaN
# 9   ['media', 'payments', 'tron-ecosystem', 'dwf-l...           NaN
# 10  ['pos', 'ftx-bankruptcy-estate', 'dwf-labs-por...           NaN
# 11  ['defi', 'stablecoin', 'asset-backed-stablecoi...           NaN
# 12  ['pos', 'platform', 'enterprise-solutions', 'z...  1.000000e+10
# 13  ['substrate', 'polkadot', 'binance-chain', 'po...           NaN
# 14  ['mineable', 'pow', 'scrypt', 'medium-of-excha...  8.400000e+07
# 15  ['mineable', 'pow', 'sha-256', 'store-of-value...  2.100000e+07
# 16  ['pos', 'smart-contracts', 'ethereum-ecosystem...           NaN
# 17  ['payments', 'stablecoin', 'asset-backed-stabl...           NaN
# 18  ['marketplace', 'centralized-exchange', 'payme...           NaN
# 19  ['medium-of-exchange', 'enterprise-solutions',...  1.000000e+11
# 20  ['medium-of-exchange', 'stablecoin', 'asset-ba...           NaN
# 21  ['pos', 'platform', 'solana-ecosystem', 'cms-h...           NaN
# 22  ['dpos', 'pos', 'platform', 'research', 'smart...  4.500000e+10
# 23  ['mineable', 'pow', 'scrypt', 'medium-of-excha...           NaN
# 24  ['media', 'payments', 'tron-ecosystem', 'dwf-l...           NaN
# 25  ['pos', 'ftx-bankruptcy-estate', 'dwf-labs-por...           NaN
# 26  ['defi', 'stablecoin', 'asset-backed-stablecoi...           NaN
# 27  ['pos', 'platform', 'enterprise-solutions', 'z...  1.000000e+10
# 28  ['substrate', 'polkadot', 'binance-chain', 'po...           NaN
# 29  ['mineable', 'pow', 'scrypt', 'medium-of-excha...  8.400000e+07
# 30  ['mineable', 'pow', 'sha-256', 'store-of-value...  2.100000e+07
# 31  ['pos', 'smart-contracts', 'ethereum-ecosystem...           NaN
# 32  ['payments', 'stablecoin', 'asset-backed-stabl...           NaN
# 33  ['marketplace', 'centralized-exchange', 'payme...           NaN
# 34  ['medium-of-exchange', 'enterprise-solutions',...  1.000000e+11
# 35  ['medium-of-exchange', 'stablecoin', 'asset-ba...           NaN
# 36  ['pos', 'platform', 'solana-ecosystem', 'cms-h...           NaN
# 37  ['dpos', 'pos', 'platform', 'research', 'smart...  4.500000e+10
# 38  ['mineable', 'pow', 'scrypt', 'medium-of-excha...           NaN
# 39  ['media', 'payments', 'tron-ecosystem', 'dwf-l...           NaN
# 40  ['pos', 'ftx-bankruptcy-estate', 'dwf-labs-por...           NaN
# 41  ['defi', 'stablecoin', 'asset-backed-stablecoi...           NaN
# 42  ['pos', 'platform', 'enterprise-solutions', 'z...  1.000000e+10
# 43  ['substrate', 'polkadot', 'binance-chain', 'po...           NaN
# 44  ['mineable', 'pow', 'scrypt', 'medium-of-excha...  8.400000e+07
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.951451e+07  1.951451e+07            False       NaN         1
# 1         1.202581e+08  1.202581e+08             True       NaN         2
# 2         8.352701e+10  8.662567e+10             True       NaN         3
# 3         1.538448e+08  1.538448e+08            False       NaN         4
# 4         5.344103e+10  9.998836e+10            False       NaN         5
# 5         2.512296e+10  2.512296e+10            False       NaN         6
# 6         4.162580e+08  5.600333e+08             True       NaN         7
# 7         3.521102e+10  3.625937e+10            False       NaN         8
# 8         1.414225e+11  1.414225e+11             True       NaN         9
# 9         8.893961e+10  8.893967e+10             True       NaN        10
# 10        3.431892e+09  5.047559e+09             True       NaN        11
# 11        5.347889e+09  5.347889e+09             True       NaN        12
# 12        9.299803e+09  1.000000e+10            False       NaN        13
# 13        1.234087e+09  1.366347e+09             True       NaN        14
# 14        7.376504e+07  8.400000e+07            False       NaN        15
# 15        1.951451e+07  1.951451e+07            False       NaN         1
# 16        1.202581e+08  1.202581e+08             True       NaN         2
# 17        8.352701e+10  8.662567e+10             True       NaN         3
# 18        1.538448e+08  1.538448e+08            False       NaN         4
# 19        5.344103e+10  9.998836e+10            False       NaN         5
# 20        2.512296e+10  2.512296e+10            False       NaN         6
# 21        4.162580e+08  5.600333e+08             True       NaN         7
# 22        3.521102e+10  3.625937e+10            False       NaN         8
# 23        1.414225e+11  1.414225e+11             True       NaN         9
# 24        8.893961e+10  8.893967e+10             True       NaN        10
# 25        3.431892e+09  5.047559e+09             True       NaN        11
# 26        5.347889e+09  5.347889e+09             True       NaN        12
# 27        9.299803e+09  1.000000e+10            False       NaN        13
# 28        1.234087e+09  1.366347e+09             True       NaN        14
# 29        7.376504e+07  8.400000e+07            False       NaN        15
# 30        1.951451e+07  1.951451e+07            False       NaN         1
# 31        1.202581e+08  1.202581e+08             True       NaN         2
# 32        8.352701e+10  8.662567e+10             True       NaN         3
# 33        1.538448e+08  1.538448e+08            False       NaN         4
# 34        5.344103e+10  9.998836e+10            False       NaN         5
# 35        2.512296e+10  2.512296e+10            False       NaN         6
# 36        4.162580e+08  5.600333e+08             True       NaN         7
# 37        3.521102e+10  3.625937e+10            False       NaN         8
# 38        1.414225e+11  1.414225e+11             True       NaN         9
# 39        8.893961e+10  8.893967e+10             True       NaN        10
# 40        3.431892e+09  5.047559e+09             True       NaN        11
# 41        5.347889e+09  5.347889e+09             True       NaN        12
# 42        9.299803e+09  1.000000e+10            False       NaN        13
# 43        1.234087e+09  1.366347e+09             True       NaN        14
# 44        7.376504e+07  8.400000e+07            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap  tvl_ratio  \
# 0                                NaN                       NaN        NaN
# 1                                NaN                       NaN        NaN
# 2                                NaN                       NaN        NaN
# 3                                NaN                       NaN        NaN
# 4                                NaN                       NaN        NaN
# 5                                NaN                       NaN        NaN
# 6                                NaN                       NaN        NaN
# 7                                NaN                       NaN        NaN
# 8                                NaN                       NaN        NaN
# 9                       7.165966e+10              6.126085e+09        NaN
# 10                      3.414167e+09              6.580624e+09        NaN
# 11                               NaN                       NaN        NaN
# 12                               NaN                       NaN        NaN
# 13                               NaN                       NaN        NaN
# 14                               NaN                       NaN        NaN
# 15                               NaN                       NaN        NaN
# 16                               NaN                       NaN        NaN
# 17                               NaN                       NaN        NaN
# 18                               NaN                       NaN        NaN
# 19                               NaN                       NaN        NaN
# 20                               NaN                       NaN        NaN
# 21                               NaN                       NaN        NaN
# 22                               NaN                       NaN        NaN
# 23                               NaN                       NaN        NaN
# 24                      7.165966e+10              6.126103e+09        NaN
# 25                      3.414167e+09              6.580355e+09        NaN
# 26                               NaN                       NaN        NaN
# 27                               NaN                       NaN        NaN
# 28                               NaN                       NaN        NaN
# 29                               NaN                       NaN        NaN
# 30                               NaN                       NaN        NaN
# 31                               NaN                       NaN        NaN
# 32                               NaN                       NaN        NaN
# 33                               NaN                       NaN        NaN
# 34                               NaN                       NaN        NaN
# 35                               NaN                       NaN        NaN
# 36                               NaN                       NaN        NaN
# 37                               NaN                       NaN        NaN
# 38                               NaN                       NaN        NaN
# 39                      7.165966e+10              6.126238e+09        NaN
# 40                      3.414167e+09              6.581336e+09        NaN
# 41                               NaN                       NaN        NaN
# 42                               NaN                       NaN        NaN
# 43                               NaN                       NaN        NaN
# 44                               NaN                       NaN        NaN
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2023-10-15T14:37:00.000Z     26904.023055          5.216794e+09
# 1   2023-10-15T14:37:00.000Z      1555.007129          2.384726e+09
# 2   2023-10-15T14:37:00.000Z         1.000208          1.052992e+10
# 3   2023-10-15T14:37:00.000Z       209.008087          3.261842e+08
# 4   2023-10-15T14:37:00.000Z         0.486535          3.671042e+08
# 5   2023-10-15T14:37:00.000Z         1.000189          1.040241e+09
# 6   2023-10-15T14:37:00.000Z        21.804841          1.476187e+08
# 7   2023-10-15T14:37:00.000Z         0.246091          7.356892e+07
# 8   2023-10-15T14:37:00.000Z         0.059279          1.112525e+08
# 9   2023-10-15T14:37:00.000Z         0.085489          1.784508e+08
# 10  2023-10-15T14:37:00.000Z         1.927447          1.597705e+07
# 11  2023-10-15T14:37:00.000Z         0.999869          4.631173e+07
# 23  2023-10-15 16:40:11.049718
# 24  2023-10-15 16:40:11.049718
# 25  2023-10-15 16:40:11.049718
# 26  2023-10-15 16:40:11.049718
# 27  2023-10-15 16:40:11.049718
# 28  2023-10-15 16:40:11.049718
# 29  2023-10-15 16:40:11.049718
# 30  2023-10-15 16:41:11.348578
# 31  2023-10-15 16:41:11.348578
# 32  2023-10-15 16:41:11.348578
# 33  2023-10-15 16:41:11.348578
# 34  2023-10-15 16:41:11.348578
# 35  2023-10-15 16:41:11.348578
# 36  2023-10-15 16:41:11.348578
# 37  2023-10-15 16:41:11.348578
# 38  2023-10-15 16:41:11.348578
# 39  2023-10-15 16:41:11.348578
# 40  2023-10-15 16:41:11.348578
# 41  2023-10-15 16:41:11.348578
# 42  2023-10-15 16:41:11.348578
# 43  2023-10-15 16:41:11.348578
# 44  2023-10-15 16:41:11.348578

# %%
#arrange floats
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#        id         name symbol                  slug  num_market_pairs  \
# 0       1      Bitcoin    BTC               bitcoin             10494
# 1    1027     Ethereum    ETH              ethereum              7551
# 2     825  Tether USDt   USDT                tether             63709
# 3    1839          BNB    BNB                   bnb              1682
# 4      52          XRP    XRP                   xrp              1114
# 5    3408         USDC   USDC              usd-coin             14451
# 6    5426       Solana    SOL                solana               535
# 7    2010      Cardano    ADA               cardano               946
# 8      74     Dogecoin   DOGE              dogecoin               806
# 9    1958         TRON    TRX                  tron               852
# 10  11419      Toncoin    TON               toncoin               158
# 11   4943          Dai    DAI  multi-collateral-dai              2671
# 12   3890      Polygon  MATIC               polygon              1002
# 13   6636     Polkadot    DOT          polkadot-new               592
# 14      2     Litecoin    LTC              litecoin              1011
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2013-08-04T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2020-04-10T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2017-09-13T00:00:00.000Z
# 10  2021-08-26T13:40:22.000Z
# 11  2019-11-22T00:00:00.000Z
# 12  2019-04-28T00:00:00.000Z
# 13  2020-08-19T00:00:00.000Z
# 14  2013-04-28T00:00:00.000Z
#
#                                                  tags         max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...                NaN
# 3   [marketplace, centralized-exchange, payments, ...                NaN
# 4   [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 5   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 6   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 7   [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 8   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 9   [media, payments, tron-ecosystem, dwf-labs-por...                NaN
# 10  [pos, ftx-bankruptcy-estate, dwf-labs-portfoli...                NaN
# 11  [defi, stablecoin, asset-backed-stablecoin, et...                NaN
# 12  [pos, platform, enterprise-solutions, zero-kno...  10000000000.00000
# 13  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 14        [mineable, pow, scrypt, medium-of-exchange]     84000000.00000
#
#     circulating_supply       total_supply  infinite_supply  platform  \
# 0       19514506.00000     19514506.00000            False       NaN
# 1      120258135.50325    120258135.50325             True       NaN
# 2    83527007239.14531  86625667477.81340             True       NaN
# 3      153844824.29324    153844824.29324            False       NaN
# 4    53441027384.00000  99988362642.00000            False       NaN
# 5    25122964175.03759  25122964175.03759            False       NaN
# 6      416258022.63107    560033261.43190             True       NaN
# 7    35211019209.81200  36259372926.66300            False       NaN
# 8   141422506383.70523 141422506383.70523             True       NaN
# 9    88939613386.48589  88939672399.90607             True       NaN
# 10    3431892087.62000   5047558528.00000             True       NaN
# 11    5347888595.74641   5347888595.74641             True       NaN
# 12    9299803030.71938  10000000000.00000            False       NaN
# 13    1234087415.08401   1366346772.38919             True       NaN
# 14      73765039.22359     84000000.00000            False       NaN
#
#     cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0          1                               NaN                       NaN
# 1          2                               NaN                       NaN
# 2          3                               NaN                       NaN
# 3          4                               NaN                       NaN
# 4          5                               NaN                       NaN
# 5          6                               NaN                       NaN
# 6          7                               NaN                       NaN
# 7          8                               NaN                       NaN
# 8          9
ote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                         -0.00111                       0.06460
# Ethereum                        -0.16355                       0.27126
# Tether USDt                      0.01092                       0.00489
# BNB                             -0.14432                       1.25967
# XRP                             -0.15734                       0.22851
# USDC                             0.00401                      -0.00316
# Solana                          -0.36602                      -0.82264
# Cardano                         -0.11098                      -0.37649
# Dogecoin                         0.03473                      -0.06711
# TRON                             0.07509                       0.10526
# Toncoin                         -0.26951                      -1.22009
# Dai                             -0.02507                      -0.01670
# Polygon                         -0.07503                      -0.54019
# Polkadot                        -0.03370                      -0.00089
# Litecoin                        -0.08441                       0.00084
#
#              quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                         -3.70779                       2.27553
# Ethereum                        -4.74256                      -3.86231
# Tether USDt                     -0.02644                       0.00477
# BNB                             -1.26355                      -1.21115
# XRP                             -6.61653                      -0.99260
# USDC                             0.02868                      -0.00491
# Solana                          -6.65025                      15.55534
# Cardano                         -4.25162                      -0.76534
# Dogecoin                        -3.17788                      -3.89287
# TRON                            -2.82215                       2.78679
# Toncoin                         -6.16377                      -1.88620
# Dai                             -0.04236                       0.05077
# Polygon                         -8.31837                      -0.44627
# Polkadot                        -7.06585                      -8.34503
# Litecoin                        -5.83843                      -3.10602
#
#              quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                          -7.56989                     -11.14308
# Ethereum                        -14.72426                     -18.78314
# Tether USDt                       0.14623                      -0.00168
# BNB                             -10.40904                     -14.24875
# XRP                             -18.26024                     -34.25775
# USDC                              0.01332                       0.01687
# Solana                           -5.98209                     -19.81361
# Cardano                         -10.20063                     -21.75098
# Dogecoin                        -14.48913                     -15.34142
# TRON                             12.91656                       7.27921
# Toncoin                          33.49201                      42.58642
# Dai                               0.01634                       0.02694
# Polygon                         -17.32697                     -34.02233
# Polkadot                        -21.02537                     -29.35370
# Litecoin                        -21.17428                     -33.16016

# %%
# we need them as stacks, changes as rows

df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h     -0.00111
#              quote.USD.percent_change_24h     0.06460
#              quote.USD.percent_change_7d     -3.70779
#              quote.USD.percent_change_30d     2.27553
#              quote.USD.percent_change_60d    -7.56989
#              quote.USD.percent_change_90d   -11.14308
# Ethereum     quote.USD.percent_change_1h     -0.16355
#              quote.USD.percent_change_24h     0.27126
#              quote.USD.percent_change_7d     -4.74256
#              quote.USD.percent_change_30d    -3.86231
#              quote.USD.percent_change_60d   -14.72426
#              quote.USD.percent_change_90d   -18.78314
# Tether USDt  quote.USD.percent_change_1h      0.01092
#              quote.USD.percent_change_24h     0.00489
#              quote.USD.percent_change_7d     -0.02644
#              quote.USD.percent_change_30d     0.00477
#              quote.USD.percent_change_60d     0.14623
#              quote.USD.percent_change_90d    -0.00168
# BNB          quote.USD.percent_change_1h     -0.14432
#              quote.USD.percent_change_24h     1.25967
#              quote.USD.percent_change_7d     -1.26355
#              quote.USD.percent_change_30d    -1.21115
#              quote.USD.percent_change_60d   -10.40904
#              quote.USD.percent_change_90d   -14.24875
# XRP          quote.USD.percent_change_1h     -0.15734
#              quote.USD.percent_change_24h     0.22851
#              quote.USD.percent_change_7d     -6.61653
#              quote.USD.percent_change_30d    -0.99260
#              quote.USD.percent_change_60d   -18.26024
#              quote.USD.percent_change_90d   -34.25775
# USDC         quote.USD.percent_change_1h      0.00401
#              quote.USD.percent_change_24h    -0.00316
#              quote.USD.percent_change_7d      0.02868
#              quote.USD.percent_change_30d    -0.00491
#              quote.USD.percent_change_60d     0.01332
#              quote.USD.percent_change_90d     0.01687
# Solana       quote.USD.percent_change_1h     -0.36602
#              quote.USD.percent_change_24h    -0.82264
#              quote.USD.percent_change_7d     -6.65025
#              quote.USD.percent_change_30d    15.55534
#              quote.USD.percent_change_60d    -5.98209
#              quote.USD.percent_change_90d   -19.81361
# Cardano      quote.USD.percent_change_1h     -0.11098
#              quote.USD.percent_change_24h    -0.37649
#              quote.USD.percent_change_7d     -4.25162
#              quote.USD.percent_change_30d    -0.76534
#              quote.USD.percent_change_60d   -10.20063
#              quote.USD.percent_change_90d   -21.75098
# Dogecoin     quote.USD.percent_change_1h      0.03473
#              quote.USD.percent_change_24h    -0.06711
#              quote.USD.percent_change_7d     -3.17788
#              quote.USD.percent_change_30d    -3.89287
#              quote.USD.percent_change_60d   -14.48913
#              quote.USD.percent_change_90d   -15.34142
# TRON         quote.USD.percent_change_1h      0.07509
#              quote.USD.percent_change_24h     0.10526
#              quote.USD.percent_change_7d     -2.82215
#              quote.USD.percent_change_30d     2.78679
#              quote.USD.percent_change_60d    12.91656
#              quote.USD.percent_change_90d     7.27921
# Toncoin      quote.USD.percent_change_1h     -0.26951
#              quote.USD.percent_change_24h    -1.22009
#              quote.USD.percent_change_7d     -6.16377
#              quote.USD.percent_change_30d    -1.88620
#              quote.USD.percent_change_60d    33.49201
#              quote.USD.percent_change_90d    42.58642
# Dai          quote.USD.percent_change_1h     -0.02507
#              quote.USD.percent_change_24h    -0.01670
#              quote.USD.percent_change_7d     -0.04236
#              quote.USD.percent_change_30d     0.05077
#              quote.USD.percent_change_60d     0.01634
#              quote.USD.percent_change_90d     0.02694
# Polygon      quote.USD.percent_change_1h     -0.07503
#              quote.USD.percent_change_24h    -0.54019
#              quote.USD.percent_change_7d     -8.31837
#              quote.USD.percent_change_30d    -0.44627
#              quote.USD.percent_change_60d   -17.32697
#              quote.USD.percent_change_90d   -34.02233
# Polkadot     quote.USD.percent_change_1h     -0.03370
#              quote.USD.percent_change_24h    -0.00089
#              quote.USD.percent_change_7d     -7.06585
#              quote.USD.percent_change_30d    -8.34503
#              quote.USD.percent_change_60d   -21.02537
#              quote.USD.percent_change_90d   -29.35370
# Litecoin     quote.USD.percent_change_1h     -0.08441
#              quote.USD.percent_change_24h     0.00084
#              quote.USD.percent_change_7d     -5.83843
#              quote.USD.percent_change_30d    -3.10602
#              quote.USD.percent_change_60d   -21.17428
#              quote.USD.percent_change_90d   -33.16016
# dtype: float64

# %%
type(df4)# can no longer treat as series
# Out:
# pandas.core.series.Series

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
#convert to frame

df5 = df4.to_frame(name='values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h   -0.00111
#             quote.USD.percent_change_24h   0.06460
#             quote.USD.percent_change_7d   -3.70779
#             quote.USD.percent_change_30d   2.27553
#             quote.USD.percent_change_60d  -7.56989
#             quote.USD.percent_change_90d -11.14308
# Ethereum    quote.USD.percent_change_1h   -0.16355
#             quote.USD.percent_change_24h   0.27126
#             quote.USD.percent_change_7d   -4.74256
#             quote.USD.percent_change_30d  -3.86231
#             quote.USD.percent_change_60d -14.72426
#             quote.USD.percent_change_90d -18.78314
# Tether USDt quote.USD.percent_change_1h    0.01092
#             quote.USD.percent_change_24h   0.00489
#             quote.USD.percent_change_7d   -0.02644
#             quote.USD.percent_change_30d   0.00477
#             quote.USD.percent_change_60d   0.14623
#             quote.USD.percent_change_90d  -0.00168
# BNB         quote.USD.percent_change_1h   -0.14432
#             quote.USD.percent_change_24h   1.25967
#             quote.USD.percent_change_7d   -1.26355
#             quote.USD.percent_change_30d  -1.21115
#             quote.USD.percent_change_60d -10.40904
#             quote.USD.percent_change_90d -14.24875
# XRP         quote.USD.percent_change_1h   -0.15734
#             quote.USD.percent_change_24h   0.22851
#             quote.USD.percent_change_7d   -6.61653
#             quote.USD.percent_change_30d  -0.99260
#             quote.USD.percent_change_60d -18.26024
#             quote.USD.percent_change_90d -34.25775
# USDC        quote.USD.percent_change_1h    0.00401
#             quote.USD.percent_change_24h  -0.00316
#             quote.USD.percent_change_7d    0.02868
#             quote.USD.percent_change_30d  -0.00491
#             quote.USD.percent_change_60d   0.01332
#             quote.USD.percent_change_90d   0.01687
# Solana      quote.USD.percent_change_1h   -0.36602
#             quote.USD.percent_change_24h  -0.82264
#             quote.USD.percent_change_7d   -6.65025
#             quote.USD.percent_change_30d  15.55534
#             quote.USD.percent_change_60d  -5.98209
#             quote.USD.percent_change_90d -19.81361
# Cardano     quote.USD.percent_change_1h   -0.11098
#             quote.USD.percent_change_24h  -0.37649
#             quote.USD.percent_change_7d   -4.25162
#             quote.USD.percent_change_30d  -0.76534
#             quote.USD.percent_change_60d -10.20063
#             quote.USD.percent_change_90d -21.75098
# Dogecoin    quote.USD.percent_change_1h    0.03473
#             quote.USD.percent_change_24h  -0.06711
#             quote.USD.percent_change_7d   -3.17788
#             quote.USD.percent_change_30d  -3.89287
#             quote.USD.percent_change_60d -14.48913
#             quote.USD.percent_change_90d -15.34142
# TRON        quote.USD.percent_change_1h    0.07509
#             quote.USD.percent_change_24h   0.10526
#             quote.USD.percent_change_7d   -2.82215
#             quote.USD.percent_change_30d   2.78679
#             quote.USD.percent_change_60d  12.91656
#             quote.USD.percent_change_90d   7.27921
# Toncoin     quote.USD.percent_change_1h   -0.26951
#             quote.USD.percent_change_24h  -1.22009
#             quote.USD.percent_change_7d   -6.16377
#             quote.USD.percent_change_30d  -1.88620
#             quote.USD.percent_change_60d  33.49201
#             quote.USD.percent_change_90d  42.58642
# Dai         quote.USD.percent_change_1h   -0.02507
#             quote.USD.percent_change_24h  -0.01670
#             quote.USD.percent_change_7d   -0.04236
#             quote.USD.percent_change_30d   0.05077
#             quote.USD.percent_change_60d   0.01634
#             quote.USD.percent_change_90d   0.02694
# Polygon     quote.USD.percent_change_1h   -0.07503
#             quote.USD.percent_change_24h  -0.54019
#             quote.USD.percent_change_7d   -8.31837
#             quote.USD.percent_change_30d  -0.44627
#             quote.USD.percent_change_60d -17.32697
#             quote.USD.percent_change_90d -34.02233
# Polkadot    quote.USD.percent_change_1h   -0.03370
#             quote.USD.percent_change_24h  -0.00089
#             quote.USD.percent_change_7d   -7.06585
#             quote.USD.percent_change_30d  -8.34503
#             quote.USD.percent_change_60d -21.02537
#             quote.USD.percent_change_90d -29.35370
# Litecoin    quote.USD.percent_change_1h   -0.08441
#             quote.USD.percent_change_24h   0.00084
#             quote.USD.percent_change_7d   -5.83843
#             quote.USD.percent_change_30d  -3.10602
#             quote.USD.percent_change_60d -21.17428
#             quote.USD.percent_change_90d -33.16016

# %%
type(df5)
# Out:
# pandas.core.frame.DataFrame

# %%
#but the name is acting as index, better to create numbers to access, basicly want how many rows we have here

df5.count()
# Out:
# values    90
# dtype: int64

# %%
#setting the index won't show all but REsetting 
index = pd.Index(range(90))

df6 = df5.set_index(index)
df6
# Out:
#       values
# 0   -0.00111
# 1    0.06460
# 2   -3.70779
# 3    2.27553
# 4   -7.56989
# 5  -11.14308
# 6   -0.16355
# 7    0.27126
# 8   -4.74256
# 9   -3.86231
# 10 -14.72426
# 11 -18.78314
# 12   0.01092
# 13   0.00489
# 14  -0.02644
# 15   0.00477
# 16   0.14623
# 17  -0.00168
# 18  -0.14432
# 19   1.25967
# 20  -1.26355
# 21  -1.21115
# 22 -10.40904
# 23 -14.24875
# 24  -0.15734
# 25   0.22851
# 26  -6.61653
# 27  -0.99260
# 28 -18.26024
# 29 -34.25775
# 30   0.00401
# 31  -0.00316
# 32   0.02868
# 33  -0.00491
# 34   0.01332
# 35   0.01687
# 36  -0.36602
# 37  -0.82264
# 38  -6.65025
# 39  15.55534
# 40  -5.98209
# 41 -19.81361
# 42  -0.11098
# 43  -0.37649
# 44  -4.25162
# 45  -0.76534
# 46 -10.20063
# 47 -21.75098
# 48   0.03473
# 49  -0.06711
# 50  -3.17788
# 51  -3.89287
# 52 -14.48913
# 53 -15.34142
# 54   0.07509
# 55   0.10526
# 56  -2.82215
# 57   2.78679
# 58  12.91656
# 59   7.27921
# 60  -0.26951
# 61  -1.22009
# 62  -6.16377
# 63  -1.88620
# 64  33.49201
# 65  42.58642
# 66  -0.02507
# 67  -0.01670
# 68  -0.04236
# 69   0.05077
# 70   0.01634
# 71   0.02694
# 72  -0.07503
# 73  -0.54019
# 74  -8.31837
# 75  -0.44627
# 76 -17.32697
# 77 -34.02233
# 78  -0.03370
# 79  -0.00089
# 80  -7.06585
# 81  -8.34503
# 82 -21.02537
# 83 -29.35370
# 84  -0.08441
# 85   0.00084
# 86  -5.83843
# 87  -3.10602
# 88 -21.17428
# 89 -33.16016

# %%
#setting the index won't show all but REsetting 
index = pd.Index(range(90))

df6 = df5.reset_index()
df6
# Out:
#            name                       level_1    values
# 0       Bitcoin   quote.USD.percent_change_1h  -0.00111
# 1       Bitcoin  quote.USD.percent_change_24h   0.06460
# 2       Bitcoin   quote.USD.percent_change_7d  -3.70779
# 3       Bitcoin  quote.USD.percent_change_30d   2.27553
# 4       Bitcoin  quote.USD.percent_change_60d  -7.56989
# 5       Bitcoin  quote.USD.percent_change_90d -11.14308
# 6      Ethereum   quote.USD.percent_change_1h  -0.16355
# 7      Ethereum  quote.USD.percent_change_24h   0.27126
# 8      Ethereum   quote.USD.percent_change_7d  -4.74256
# 9      Ethereum  quote.USD.percent_change_30d  -3.86231
# 10     Ethereum  quote.USD.percent_change_60d -14.72426
# 11     Ethereum  quote.USD.percent_change_90d -18.78314
# 12  Tether USDt   quote.USD.percent_change_1h   0.01092
# 13  Tether USDt  quote.USD.percent_change_24h   0.00489
# 14  Tether USDt   quote.USD.percent_change_7d  -0.02644
# 15  Tether USDt  quote.USD.percent_change_30d   0.00477
# 16  Tether USDt  quote.USD.percent_change_60d   0.14623
# 17  Tether USDt  quote.USD.percent_change_90d  -0.00168
# 18          BNB   quote.USD.percent_change_1h  -0.14432
# 19          BNB  quote.USD.percent_change_24h   1.25967
# 20          BNB   quote.USD.percent_change_7d  -1.26355
# 21          BNB  quote.USD.percent_change_30d  -1.21115
# 22          BNB  quote.USD.percent_change_60d -10.40904
# 23          BNB  quote.USD.percent_change_90d -14.24875
# 24          XRP   quote.USD.percent_change_1h  -0.15734
# 25          XRP  quote.USD.percent_change_24h   0.22851
# 26          XRP   quote.USD.percent_change_7d  -6.61653
# 27          XRP  quote.USD.percent_change_30d  -0.99260
# 28          XRP  quote.USD.percent_change_60d -18.26024
# 29          XRP  quote.USD.percent_change_90d -34.25775
# 30         USDC   quote.USD.percent_change_1h   0.00401
# 31         USDC  quote.USD.percent_change_24h  -0.00316
# 32         USDC   quote.USD.percent_change_7d   0.02868
# 33         USDC  quote.USD.percent_change_30d  -0.00491
# 34         USDC  quote.USD.percent_change_60d   0.01332
# 35         USDC  quote.USD.percent_change_90d   0.01687
# 36       Solana   quote.USD.percent_change_1h  -0.36602
# 37       Solana  quote.USD.percent_change_24h  -0.82264
# 38       Solana   quote.USD.percent_change_7d  -6.65025
# 39       Solana  quote.USD.percent_change_30d  15.55534
# 40       Solana  quote.USD.percent_change_60d  -5.98209
# 41       Solana  quote.USD.percent_change_90d -19.81361
# 42      Cardano   quote.USD.percent_change_1h  -0.11098
# 43      Cardano  quote.USD.percent_change_24h  -0.37649
# 44      Cardano   quote.USD.percent_change_7d  -4.25162
# 45      Cardano  quote.USD.percent_change_30d  -0.76534
# 46      Cardano  quote.USD.percent_change_60d -10.20063
# 47      Cardano  quote.USD.percent_change_90d -21.75098
# 48     Dogecoin   quote.USD.percent_change_1h   0.03473
# 49     Dogecoin  quote.USD.percent_change_24h  -0.06711
# 50     Dogecoin   quote.USD.percent_change_7d  -3.17788
# 51     Dogecoin  quote.USD.percent_change_30d  -3.89287
# 52     Dogecoin  quote.USD.percent_change_60d -14.48913
# 53     Dogecoin  quote.USD.percent_change_90d -15.34142
# 54         TRON   quote.USD.percent_change_1h   0.07509
# 55         TRON  quote.USD.percent_change_24h   0.10526
# 56         TRON   quote.USD.percent_change_7d  -2.82215
# 57         TRON  quote.USD.percent_change_30d   2.78679
# 58         TRON  quote.USD.percent_change_60d  12.91656
# 59         TRON  quote.USD.percent_change_90d   7.27921
# 60      Toncoin   quote.USD.percent_change_1h  -0.26951
# 61      Toncoin  quote.USD.percent_change_24h  -1.22009
# 62      Toncoin   quote.USD.percent_change_7d  -6.16377
# 63      Toncoin  quote.USD.percent_change_30d  -1.88620
# 64      Toncoin  quote.USD.percent_change_60d  33.49201
# 65      Toncoin  quote.USD.percent_change_90d  42.58642
# 66          Dai   quote.USD.percent_change_1h  -0.02507
# 67          Dai  quote.USD.percent_change_24h  -0.01670
# 68          Dai   quote.USD.percent_change_7d  -0.04236
# 69          Dai  quote.USD.percent_change_30d   0.05077
# 70          Dai  quote.USD.percent_change_60d   0.01634
# 71          Dai  quote.USD.percent_change_90d   0.02694
# 72      Polygon   quote.USD.percent_change_1h  -0.07503
# 73      Polygon  quote.USD.percent_change_24h  -0.54019
# 74      Polygon   quote.USD.percent_change_7d  -8.31837
# 75      Polygon  quote.USD.percent_change_30d  -0.44627
# 76      Polygon  quote.USD.percent_change_60d -17.32697
# 77      Polygon  quote.USD.percent_change_90d -34.02233
# 78     Polkadot   quote.USD.percent_change_1h  -0.03370
# 79     Polkadot  quote.USD.percent_change_24h  -0.00089
# 80     Polkadot   quote.USD.percent_change_7d  -7.06585
# 81     Polkadot  quote.USD.percent_change_30d  -8.34503
# 82     Polkadot  quote.USD.percent_change_60d -21.02537
# 83     Polkadot  quote.USD.percent_change_90d -29.35370
# 84     Litecoin   quote.USD.percent_change_1h  -0.08441
# 85     Litecoin  quote.USD.percent_change_24h   0.00084
# 86     Litecoin   quote.USD.percent_change_7d  -5.83843
# 87     Litecoin  quote.USD.percent_change_30d  -3.10602
# 88     Litecoin  quote.USD.percent_change_60d -21.17428
# 89     Litecoin  quote.USD.percent_change_90d -33.16016

# %%
#rename level_1 column

df7 = df6.rename(columns= {'level_1' : 'percent_change'})
df7
# Out:
#            name                percent_change    values
# 0       Bitcoin   quote.USD.percent_change_1h  -0.00111
# 1       Bitcoin  quote.USD.percent_change_24h   0.06460
# 2       Bitcoin   quote.USD.percent_change_7d  -3.70779
# 3       Bitcoin  quote.USD.percent_change_30d   2.27553
# 4       Bitcoin  quote.USD.percent_change_60d  -7.56989
# 5       Bitcoin  quote.USD.percent_change_90d -11.14308
# 6      Ethereum   quote.USD.percent_change_1h  -0.16355
# 7      Ethereum  quote.USD.percent_change_24h   0.27126
# 8      Ethereum   quote.USD.percent_change_7d  -4.74256
# 9      Ethereum  quote.USD.percent_change_30d  -3.86231
# 10     Ethereum  quote.USD.percent_change_60d -14.72426
# 11     Ethereum  quote.USD.percent_change_90d -18.78314
# 12  Tether USDt   quote.USD.percent_change_1h   0.01092
# 13  Tether USDt  quote.USD.percent_change_24h   0.00489
# 14  Tether USDt   quote.USD.percent_change_7d  -0.02644
# 15  Tether USDt  quote.USD.percent_change_30d   0.00477
# 16  Tether USDt  quote.USD.percent_change_60d   0.14623
# 17  Tether USDt  quote.USD.percent_change_90d  -0.00168
# 18          BNB   quote.USD.percent_change_1h  -0.14432
# 19          BNB  quote.USD.percent_change_24h   1.25967
# 20          BNB   quote.USD.percent_change_7d  -1.26355
# 21          BNB  quote.USD.percent_change_30d  -1.21115
# 22          BNB  quote.USD.percent_change_60d -10.40904
# 23          BNB  quote.USD.percent_change_90d -14.24875
# 24          XRP   quote.USD.percent_change_1h  -0.15734
# 25          XRP  quote.USD.percent_change_24h   0.22851
# 26          XRP   quote.USD.percent_change_7d  -6.61653
# 27          XRP  quote.USD.percent_change_30d  -0.99260
# 28          XRP  quote.USD.percent_change_60d -18.26024
# 29          XRP  quote.USD.percent_change_90d -34.25775
# 30         USDC   quote.USD.percent_change_1h   0.00401
# 31         USDC  quote.USD.percent_change_24h  -0.00316
# 32         USDC   quote.USD.percent_change_7d   0.02868
# 33         USDC  quote.USD.percent_change_30d  -0.00491
# 34         USDC  quote.USD.percent_change_60d   0.01332
# 35         USDC  quote.USD.percent_change_90d   0.01687
# 36       Solana   quote.USD.percent_change_1h  -0.36602
# 37       Solana  quote.USD.percent_change_24h  -0.82264
# 38       Solana   quote.USD.percent_change_7d  -6.65025
# 39       Solana  quote.USD.percent_change_30d  15.55534
# 40       Solana  quote.USD.percent_change_60d  -5.98209
# 41       Solana  quote.USD.percent_change_90d -19.81361
# 42      Cardano   quote.USD.percent_change_1h  -0.11098
# 43      Cardano  quote.USD.percent_change_24h  -0.37649
# 44      Cardano   quote.USD.percent_change_7d  -4.25162
# 45      Cardano  quote.USD.percent_change_30d  -0.76534
# 46      Cardano  quote.USD.percent_change_60d -10.20063
# 47      Cardano  quote.USD.percent_change_90d -21.75098
# 48     Dogecoin   quote.USD.percent_change_1h   0.03473
# 49     Dogecoin  quote.USD.percent_change_24h  -0.06711
# 50     Dogecoin   quote.USD.percent_change_7d  -3.17788
# 51     Dogecoin  quote.USD.percent_change_30d  -3.89287
# 52     Dogecoin  quote.USD.percent_change_60d -14.48913
# 53     Dogecoin  quote.USD.percent_change_90d -15.34142
# 54         TRON   quote.USD.percent_change_1h   0.07509
# 55         TRON  quote.USD.percent_change_24h   0.10526
# 56         TRON   quote.USD.percent_change_7d  -2.82215
# 57         TRON  quote.USD.percent_change_30d   2.78679
# 58         TRON  quote.USD.percent_change_60d  12.91656
# 59         TRON  quote.USD.percent_change_90d   7.27921
# 60      Toncoin   quote.USD.percent_change_1h  -0.26951
# 61      Toncoin  quote.USD.percent_change_24h  -1.22009
# 62      Toncoin   quote.USD.percent_change_7d  -6.16377
# 63      Toncoin  quote.USD.percent_change_30d  -1.88620
# 64      Toncoin  quote.USD.percent_change_60d  33.49201
# 65      Toncoin  quote.USD.percent_change_90d  42.58642
# 66          Dai   quote.USD.percent_change_1h  -0.02507
# 67          Dai  quote.USD.percent_change_24h  -0.01670
# 68          Dai   quote.USD.percent_change_7d  -0.04236
# 69          Dai  quote.USD.percent_change_30d   0.05077
# 70          Dai  quote.USD.percent_change_60d   0.01634
# 71          Dai  quote.USD.percent_change_90d   0.02694
# 72      Polygon   quote.USD.percent_change_1h  -0.07503
# 73      Polygon  quote.USD.percent_change_24h  -0.54019
# 74      Polygon   quote.USD.percent_change_7d  -8.31837
# 75      Polygon  quote.USD.percent_change_30d  -0.44627
# 76      Polygon  quote.USD.percent_change_60d -17.32697
# 77      Polygon  quote.USD.percent_change_90d -34.02233
# 78     Polkadot   quote.USD.percent_change_1h  -0.03370
# 79     Polkadot  quote.USD.percent_change_24h  -0.00089
# 80     Polkadot   quote.USD.percent_change_7d  -7.06585
# 81     Polkadot  quote.USD.percent_change_30d  -8.34503
# 82     Polkadot  quote.USD.percent_change_60d -21.02537
# 83     Polkadot  quote.USD.percent_change_90d -29.35370
# 84     Litecoin   quote.USD.percent_change_1h  -0.08441
# 85     Litecoin  quote.USD.percent_change_24h   0.00084
# 86     Litecoin   quote.USD.percent_change_7d  -5.83843
# 87     Litecoin  quote.USD.percent_change_30d  -3.10602
# 88     Litecoin  quote.USD.percent_change_60d -21.17428
# 89     Litecoin  quote.USD.percent_change_90d -33.16016

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d'], ['1h', '24h', '7d', '30d', '60d', '90d'])
df7
# Out:
#            name percent_change    values
# 0       Bitcoin             1h  -0.00111
# 1       Bitcoin            24h   0.06460
# 2       Bitcoin             7d  -3.70779
# 3       Bitcoin            30d   2.27553
# 4       Bitcoin            60d  -7.56989
# 5       Bitcoin            90d -11.14308
# 6      Ethereum             1h  -0.16355
# 7      Ethereum            24h   0.27126
# 8      Ethereum             7d  -4.74256
# 9      Ethereum            30d  -3.86231
# 10     Ethereum            60d -14.72426
# 11     Ethereum            90d -18.78314
# 12  Tether USDt             1h   0.01092
# 13  Tether USDt            24h   0.00489
# 14  Tether USDt             7d  -0.02644
# 15  Tether USDt            30d   0.00477
# 16  Tether USDt            60d   0.14623
# 17  Tether USDt            90d  -0.00168
# 18          BNB             1h  -0.14432
# 19          BNB            24h   1.25967
# 20          BNB             7d  -1.26355
# 21          BNB            30d  -1.21115
# 22          BNB            60d -10.40904
# 23          BNB            90d -14.24875
# 24          XRP             1h  -0.15734
# 25          XRP            24h   0.22851
# 26          XRP             7d  -6.61653
# 27          XRP            30d  -0.99260
# 28          XRP            60d -18.26024
# 29          XRP            90d -34.25775
# 30         USDC             1h   0.00401
# 31         USDC            24h  -0.00316
# 32         USDC             7d   0.02868
# 33         USDC            30d  -0.00491
# 34         USDC            60d   0.01332
# 35         USDC            90d   0.01687
# 36       Solana             1h  -0.36602
# 37       Solana            24h  -0.82264
# 38       Solana             7d  -6.65025
# 39       Solana            30d  15.55534
# 40       Solana            60d  -5.98209
# 41       Solana            90d -19.81361
# 42      Cardano             1h  -0.11098
# 43      Cardano            24h  -0.37649
# 44      Cardano             7d  -4.25162
# 45      Cardano            30d  -0.76534
# 46      Cardano            60d -10.20063
# 47      Cardano            90d -21.75098
# 48     Dogecoin             1h   0.03473
# 49     Dogecoin            24h  -0.06711
# 50     Dogecoin             7d  -3.17788
# 51     Dogecoin            30d  -3.89287
# 52     Dogecoin            60d -14.48913
# 53     Dogecoin            90d -15.34142
# 54         TRON             1h   0.07509
# 55         TRON            24h   0.10526
# 56         TRON             7d  -2.82215
# 57         TRON            30d   2.78679
# 58         TRON            60d  12.91656
# 59         TRON            90d   7.27921
# 60      Toncoin             1h  -0.26951
# 61      Toncoin            24h  -1.22009
# 62      Toncoin             7d  -6.16377
# 63      Toncoin            30d  -1.88620
# 64      Toncoin            60d  33.49201
# 65      Toncoin            90d  42.58642
# 66          Dai             1h  -0.02507
# 67          Dai            24h  -0.01670
# 68          Dai             7d  -0.04236
# 69          Dai            30d   0.05077
# 70          Dai            60d   0.01634
# 71          Dai            90d   0.02694
# 72      Polygon             1h  -0.07503
# 73      Polygon            24h  -0.54019
# 74      Polygon             7d  -8.31837
# 75      Polygon            30d  -0.44627
# 76      Polygon            60d -17.32697
# 77      Polygon            90d -34.02233
# 78     Polkadot             1h  -0.03370
# 79     Polkadot            24h  -0.00089
# 80     Polkadot             7d  -7.06585
# 81     Polkadot            30d  -8.34503
# 82     Polkadot            60d -21.02537
# 83     Polkadot            90d -29.35370
# 84     Litecoin             1h  -0.08441
# 85     Litecoin            24h   0.00084
# 86     Litecoin             7d  -5.83843
# 87     Litecoin            30d  -3.10602
# 88     Litecoin            60d -21.17428
# 89     Litecoin            90d -33.16016

# %%
#Visualizations

import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')
# Out:
# /Users/sahinbasol/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#take specific columns

df10 = df12[['name', 'quote.USD.price', 'timestamp']]
df10 = df10.query("name == 'Bitcoin'")
pd.set_option('display.float_format', lambda x: '%.5f' % x)
df10
# Out:
#        name  quote.USD.price                   timestamp
# 0   Bitcoin      26904.02306  2023-10-15 16:39:10.705820
# 15  Bitcoin      26896.73326  2023-10-15 16:40:11.049718
# 30  Bitcoin      26898.25224  2023-10-15 16:41:11.348578

# %%
df11 = df[['name', 'quote.USD.price', 'timestamp']]
df11 = df11.query("name == 'Bitcoin'")
df11
# Out:
#       name  quote.USD.price                  timestamp
# 0  Bitcoin      26898.25224 2023-10-15 16:41:11.348578

# %%
sns.set_theme(style= 'darkgrid')
sns.lineplot(x='timestamp', y='quote.USD.price', data= df10)
plt.gca().yaxis.set_major_formatter('{:.2f}'.format)

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'timestamp' is a datetime column in your DataFrame
# You may need to convert it to datetime if it's not already
df10['timestamp'] = pd.to_datetime(df10['timestamp'])
plt.gca().yaxis.set_major_formatter('{:.2f}'.format)

# Set the Seaborn theme
sns.set_theme(style='darkgrid')

# Create the lineplot with custom number formatting
sns.lineplot(x=df10['timestamp'].dt.strftime('%H:%M:%S'), y='quote.USD.price', data=df10)

# Format the x-axis tick labels to display only hour:minute:second
#plt.xticks(rotation=45)  # Rotates x-axis labels for better readability

# Show the plot
plt.show()
